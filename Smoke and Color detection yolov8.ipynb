# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\BAPS\Documents

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data=r'D:/Smoke detection yolov8/data.yaml', epochs=5, imgsz=640, lr0=0.01)
# Out:
# Ultralytics YOLOv8.0.184  Python-3.11.5 torch-2.0.1+cpu CPU (Intel Core(TM) i5-8365U 1.60GHz)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r'C:\Users\BAPS\runs\detect\train2\weights\best.pt')  # load a custom model

# Predict with the model
results = model(r'D:\Smoke detection yolov8\image.jpg', save=True, conf=0.5)  # predict on an image
# Out:
# image 1/1 D:\Smoke detection yolov8\image.jpg: 640x640 1 smoke, 262.2ms
# Speed: 6.9ms preprocess, 262.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\BAPS\runs\detect\predict2

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r'C:\Users\BAPS\runs\detect\train2\weights\best.pt')  # load a custom model

# Predict with the model
results = model(r'D:\Smoke detection yolov8\video.mp4', save=True, conf=0.5)  # predict on an image
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/390) D:\Smoke detection yolov8\video.mp4: 384x640 (no detections), 363.6ms
# video 1/1 (2/390) D:\Smoke detection yolov8\video.mp4: 384x640 1 smoke, 141.1ms
# video 1/1 (3/390) D:\Smoke detection yolov8\video.mp4: 384x640 (no detections), 138.5ms
# video 1/1 (4/390) D:\Smoke detection yolov8\video.mp4: 384x640 (no detections), 128.7ms
# video 1/1 (5/390) D:\Smoke detection yolov8\video.mp4: 384x640 1 smoke, 135.4ms
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r'C:\Users\BAPS\runs\detect\train2\weights\best.pt')  # load a custom model

# Predict with the model
results = model(r'D:\Smoke detection yolov8\video7.mp4', save=True, conf=0.5)  # predict on an image
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/747) D:\Smoke detection yolov8\video7.mp4: 640x384 (no detections), 281.1ms
# video 1/1 (2/747) D:\Smoke detection yolov8\video7.mp4: 640x384 (no detections), 155.7ms
# video 1/1 (3/747) D:\Smoke detection yolov8\video7.mp4: 640x384 (no detections), 128.1ms
# video 1/1 (4/747) D:\Smoke detection yolov8\video7.mp4: 640x384 (no detections), 134.7ms
# ...

# %%
pip install opencv-python
pip install numpy

# %%
import numpy as np
import cv2


# read the image
image = cv2.imread("examples/1.jpg")
# convert from BGR to HSV color space
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# lower and upper limits for the white color
lower_limit = np.array([75, 0, 99])
upper_limit = np.array([179, 62, 255])

# create a mask for the specified color range
mask = cv2.inRange(hsv_image, lower_limit, upper_limit)
# get the bounding box from the mask image
bbox = cv2.boundingRect(mask)

# if we get a bounding box, use it to draw a rectangle on the image
if bbox is not None:
    print("Object detected")
    x, y, w, h = bbox
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
else:
    print("Object not detected")

cv2.imshow('image', image)
cv2.waitKey(0)

# %%
import numpy as np
import cv2


# initialize the video capture object
cap = cv2.VideoCapture("examples/1.mp4")

# grab the width, height, and fps of the frames in the video stream.
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# initialize the FourCC and a video writer object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output = cv2.VideoWriter('output.mp4', fourcc, fps, (frame_width, frame_height))

while True:
    ret, frame = cap.read()
    
    if not ret:
        print("There is no more frame to read, exiting...")
        break

    # convert from BGR to HSV color space
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # lower and upper limits for the blue color
    lower_limit = np.array([99, 135, 51])
    upper_limit = np.array([116, 226, 255])

    mask = cv2.inRange(hsv_frame, lower_limit, upper_limit)
    bbox = cv2.boundingRect(mask)

    # if we get a bounding box, use it to draw a rectangle on the image
    if bbox is not None:
        x, y, w, h = bbox
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    else:
        print("Object not detected")

    cv2.imshow('frame', frame)
    # write the frame to the output file
    output.write(frame)
    if cv2.waitKey(30) == ord('q'):
        break

cap.release()
output.release()
cv2.destroyAllWindows()
